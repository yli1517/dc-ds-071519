# %% [markdown]
# ![seaborn](https://d2h0cx97tjks2p.cloudfront.net/blogs/wp-content/uploads/sites/2/2018/07/seaborn.png)
# # The good, the bad, the seaborn
#
#
# #### Whats wrong with this data visualization? (hint: so many things)
# ![bad image](https://pbs.twimg.com/media/DNTFhGaXcAEbrMO.jpg)
#
# Learning goals:
# - Create a list of best practices for data visualization
# - Identify the differences between matplotlib and seaborn
# - Create a visualization with seaborn, applying best practices

# %% [markdown]
# ## Goal 1: Create a list of best practices for data visualization
#
# Documenting best practices:
#
# In groups: [article 1](https://www.jackhagley.com/What-s-the-difference-between-an-Infographic-and-a-Data-Visualisation), [article 2](https://thoughtbot.com/blog/analyzing-minards-visualization-of-napoleons-1812-march), [article 3](http://dataremixed.com/2016/04/the-design-of-everyday-visualizations/), [article 4](https://visme.co/blog/data-storytelling-tips/),  article 5: Visualizations That Really Work.pdf (in folder), [article 6](https://www.tableau.com/learn/articles/best-beautiful-data-visualization-examples)
#
# To fill in: [Best practices deck](https://docs.google.com/presentation/d/1uICq6Rqxu_YqZvreG-82QMTTV3xPXSC0lrjHRqfDuRo/edit?usp=sharing)

# %% [markdown]
# ## Goal 2:  Identify differences between seaborn & matplotlib
#
#
# ### Two code examples to accomplish the same plot:
#
# **Resources:**
# - [python graph gallery on seaborn](https://python-graph-gallery.com/seaborn/)
# - [seaborn](https://seaborn.pydata.org/)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# Load in data
tips = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Matplotlib:

# Initialize Figure and Axes object
fig, ax = plt.subplots()

# Create violinplot
ax.violinplot(tips["total_bill"], vert=False)

# Show the plot
plt.show()

# %%
# Seaborn:

import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
tips = sns.load_dataset("tips")

# Create violinplot
sns.violinplot(x = "total_bill", data=tips)

# Show the plot
plt.show()

# %% [markdown]
# ### In depth comparison:
#
# #### Groups 1:3
#
# For each plot:
# - How is the code to create it different from the maplotlib code?
# - What are the customization options?
# - What are the top 3 most important customization options to know(with code) ?
#
# Group 1 - [histograms](https://python-graph-gallery.com/histogram/)<br>
# Group 2 - [scatter plot](https://python-graph-gallery.com/scatter-plot/)<br>
# Group 3 - [boxplot](http://python-graph-gallery.com/boxplot/)<br>
#
# #### Groups 4:5
# - What new vocabulary was introduced in these posts?
# - What is the benefit of these new options?
# - What code/options do you need to know?
#
# Group 4 - [diverging, sequential, discrete color palattes](https://python-graph-gallery.com/101-make-a-color-palette-with-seaborn/)<br>
# Group 5 - [seaborn themes](https://python-graph-gallery.com/104-seaborn-themes/) <br>
#
# #### Group 6:
# [seaborn themes w matplotlib](https://python-graph-gallery.com/106-seaborn-style-on-matplotlib-plot/)
# How does this work?
#
# _Time to work:_ 15 minutes <br>
# _Time to discuss as large group:_ 10 minutes

# %%
# sns
import seaborn as sns
tips = sns.load_dataset('tips')
sns.scatterplot(y=tips['tip'], x=tips['total_bill'], hue = tips['sex'])
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# mlp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
plt.plot()
# Out:
# []

# %%
import matplotlib.pyplot as plt
import pandas as pd

groups = tips.groupby('sex')

fig1=plt.figure()
plt.plot()

for name, group in groups:
    plt.scatter(group['total_bill'], group['tip'], marker='o', label = name)
    plt.legend()

plt.xlabel('total bill')
plt.ylabel('tip')
plt.show()
fig1.savefig("scatter_male_female.png")
plt.clf()

# %%
import matplotlib.pyplot as plt
import pandas as pd

groups = tips.groupby('sex')

fig1=plt.figure()
plt.plot()

for name, group in groups:
    plt.scatter(group['total_bill'], group['tip'], marker='o', label = name)
#     plt.legend()

plt.show()
# fig1.savefig("scatter_male_female.png")
# plt.clf()

# %%
plt.scatter(tips['total_bill'], tips['tip'], color = 'purple')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size color
# 0         16.99  1.01  Female     No   Sun  Dinner     2   red
# 1         10.34  1.66    Male     No   Sun  Dinner     3  blue
# 2         21.01  3.50    Male     No   Sun  Dinner     3  blue
# 3         23.68  3.31    Male     No   Sun  Dinner     2  blue
# 4         24.59  3.61  Female     No   Sun  Dinner     4   red
# 5         25.29  4.71    Male     No   Sun  Dinner     4  blue
# 6          8.77  2.00    Male     No   Sun  Dinner     2  blue
# 7         26.88  3.12    Male     No   Sun  Dinner     4  blue
# 8         15.04  1.96    Male     No   Sun  Dinner     2  blue
# 9         14.78  3.23    Male     No   Sun  Dinner     2  blue
# 10        10.27  1.71    Male     No   Sun  Dinner     2  blue
# 11        35.26  5.00  Female     No   Sun  Dinner     4   red
# 12        15.42  1.57    Male     No   Sun  Dinner     2  blue
# 13        18.43  3.00    Male     No   Sun  Dinner     4  blue
# 14        14.83  3.02  Female     No   Sun  Dinner     2   red
# 15        21.58  3.92    Male     No   Sun  Dinner     2  blue
# 16        10.33  1.67  Female     No   Sun  Dinner     3   red
# 17        16.29  3.71    Male     No   Sun  Dinner     3  blue
# 18        16.97  3.50  Female     No   Sun  Dinner     3   red
# 19        20.65  3.35    Male     No   Sat  Dinner     3  blue
# 20        17.92  4.08    Male     No   Sat  Dinner     2  blue
# 21        20.29  2.75  Female     No   Sat  Dinner     2   red
# 22        15.77  2.23  Female     No   Sat  Dinner     2   red
# 23        39.42  7.58    Male     No   Sat  Dinner     4  blue
# 24        19.82  3.18    Male     No   Sat  Dinner     2  blue
# 25        17.81  2.34    Male     No   Sat  Dinner     4  blue
# 26        13.37  2.00    Male     No   Sat  Dinner     2  blue
# 27        12.69  2.00    Male     No   Sat  Dinner     2  blue
# 28        21.70  4.30    Male     No   Sat  Dinner     2  blue
# 29        19.65  3.00  Female     No   Sat  Dinner     2   red
# ..          ...   ...     ...    ...   ...     ...   ...   ...
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3   red
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2   red
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5  blue
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2  blue
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2  blue
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4   red
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2  blue
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2   red
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1  blue
# 223       15.98  3.00  Female     No   Fri   Lunch     3   red
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2  blue
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2   red
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2   red
# 227       20.45  3.00    Male     No   Sat  Dinner     4  blue
# 228       13.28  2.72    Male     No   Sat  Dinner     2  blue
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2   red
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4  blue
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3  blue
# 232       11.61  3.39    Male     No   Sat  Dinner     2  blue
# 233       10.77  1.47    Male     No   Sat  Dinner     2  blue
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2  blue
# 235       10.07  1.25    Male     No   Sat  Dinner     2  blue
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2  blue
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2  blue
# 238       35.83  4.67  Female     No   Sat  Dinner     3   red
# 239       29.03  5.92    Male     No   Sat  Dinner     3  blue
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   red
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  blue
# 242       17.82  1.75    Male     No   Sat  Dinner     2  blue
# 243       18.78  3.00  Female     No  Thur  Dinner     2   red
#
# [244 rows x 8 columns]

# %%
groups = tips.groupby('sex')

fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group['total_bill'], group['tip'], marker='.', linestyle='', ms=12, label = name)
    
ax.legend()

plt.show()

# %%
groups = tips.groupby('sex')

# Plot
fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group.x, group.y, marker='o', linestyle='', ms=12, label=name)
ax.legend()

plt.show()

# %% [markdown]
# ## Goal 3: Create a visualization with seaborn, applying best practices
#
# [exercise from data world](https://data.world/makeovermonday/2018w37-paying-the-president)
#
# code to read in the data:
#
# ```
# import pandas as pd
# df = pd.read_excel('https://query.data.world/s/5qxp2ldwsel3ow2pq5mkvfas2rfaup')
# ```

# %% [markdown]
# ## Reflection:
# (message Data Science Coaches)
# - What worked from this training?
# - What can you apply moving forward?
# - What's one concept you would like to practice more?

# %% [markdown]
# #### For extra fun:
# [visualization challenges](http://www.storytellingwithdata.com/blog/2019/3/1/swdchallenge-visualize-this-data)
#
# [seaborn cheatsheet](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Seaborn_Cheat_Sheet.pdf)
